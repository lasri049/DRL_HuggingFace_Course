# %%
# %%capture
# !pip install pyglet==1.5.1
# !pip3 install pyvirtualdisplay
# !apt install python-opengl
# !sudo apt-get update
# !apt install xvfb
# !apt install ffmpeg

# %%
# %%capture
# Additional dependencies for RL-Baselines zoo
# !apt-get install swig cmake freeglut3-dev

# %%
# Virtual Display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400,900))
virtual_display.start()

# %%
# !git clone https://github.com/DLR-RM/rl-baselines3-zoo
# Out:
# Cloning into 'rl-baselines3-zoo'...
# remote: Enumerating objects: 4111, done.
# remote: Counting objects: 100% (288/288), done.
# remote: Compressing objects: 100% (145/145), done.
# remote: Total 4111 (delta 173), reused 221 (delta 131), pack-reused 3823
# Receiving objects: 100% (4111/4111), 2.81 MiB | 638.00 KiB/s, done.
# Resolving deltas: 100% (2650/2650), done.

# %%
# %cd /content/rl-baselines3-zoo/
# Out:
# /content/rl-baselines3-zoo

# %%
# %%capture
# !pip install -r requirements.txt
# !pip install huggingface_sb3

# %%
# !python train.py --algo dqn --env SpaceInvadersNoFrameskip-v4 -f logs/
# Out:
# Streaming output truncated to the last 5000 lines.
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 363      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2876     |
# |    fps              | 208      |
# |    time_elapsed     | 2987     |
# |    total_timesteps  | 621979   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0821   |
# |    n_updates        | 152994   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 365      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2880     |
# |    fps              | 208      |
# |    time_elapsed     | 2992     |
# |    total_timesteps  | 622997   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0351   |
# |    n_updates        | 153249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 366      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2884     |
# |    fps              | 208      |
# |    time_elapsed     | 2996     |
# |    total_timesteps  | 623916   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0211   |
# |    n_updates        | 153478   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 360      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2888     |
# |    fps              | 208      |
# |    time_elapsed     | 3001     |
# |    total_timesteps  | 624854   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 153713   |
# ----------------------------------
# Eval num_timesteps=625000, episode_reward=345.00 +/- 113.09
# Episode length: 2937.60 +/- 758.34
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.94e+03 |
# |    mean_reward      | 345      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 625000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00825  |
# |    n_updates        | 153749   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04e+03 |
# |    ep_rew_mean      | 360      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2892     |
# |    fps              | 207      |
# |    time_elapsed     | 3014     |
# |    total_timesteps  | 625879   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 153969   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 362      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2896     |
# |    fps              | 207      |
# |    time_elapsed     | 3018     |
# |    total_timesteps  | 626783   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0751   |
# |    n_updates        | 154195   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04e+03 |
# |    ep_rew_mean      | 362      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2900     |
# |    fps              | 207      |
# |    time_elapsed     | 3021     |
# |    total_timesteps  | 627528   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0643   |
# |    n_updates        | 154381   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 370      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2904     |
# |    fps              | 207      |
# |    time_elapsed     | 3031     |
# |    total_timesteps  | 629776   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0248   |
# |    n_updates        | 154943   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 370      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2908     |
# |    fps              | 207      |
# |    time_elapsed     | 3037     |
# |    total_timesteps  | 631099   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0249   |
# |    n_updates        | 155274   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 372      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2912     |
# |    fps              | 207      |
# |    time_elapsed     | 3041     |
# |    total_timesteps  | 631989   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0402   |
# |    n_updates        | 155497   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 375      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2916     |
# |    fps              | 207      |
# |    time_elapsed     | 3047     |
# |    total_timesteps  | 633192   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0223   |
# |    n_updates        | 155797   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 378      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2920     |
# |    fps              | 207      |
# |    time_elapsed     | 3052     |
# |    total_timesteps  | 634207   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0249   |
# |    n_updates        | 156051   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 376      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2924     |
# |    fps              | 207      |
# |    time_elapsed     | 3056     |
# |    total_timesteps  | 635157   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0256   |
# |    n_updates        | 156289   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 374      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2928     |
# |    fps              | 207      |
# |    time_elapsed     | 3060     |
# |    total_timesteps  | 635974   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00868  |
# |    n_updates        | 156493   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 375      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2932     |
# |    fps              | 207      |
# |    time_elapsed     | 3064     |
# |    total_timesteps  | 636913   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0296   |
# |    n_updates        | 156728   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 373      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2936     |
# |    fps              | 207      |
# |    time_elapsed     | 3069     |
# |    total_timesteps  | 638067   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0266   |
# |    n_updates        | 157016   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 374      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2940     |
# |    fps              | 207      |
# |    time_elapsed     | 3072     |
# |    total_timesteps  | 638758   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0415   |
# |    n_updates        | 157189   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 377      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2944     |
# |    fps              | 207      |
# |    time_elapsed     | 3080     |
# |    total_timesteps  | 640374   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0246   |
# |    n_updates        | 157593   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 382      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2948     |
# |    fps              | 207      |
# |    time_elapsed     | 3084     |
# |    total_timesteps  | 641280   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.017    |
# |    n_updates        | 157819   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 387      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2952     |
# |    fps              | 207      |
# |    time_elapsed     | 3089     |
# |    total_timesteps  | 642494   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.025    |
# |    n_updates        | 158123   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 388      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2956     |
# |    fps              | 207      |
# |    time_elapsed     | 3093     |
# |    total_timesteps  | 643268   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0377   |
# |    n_updates        | 158316   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 387      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2960     |
# |    fps              | 207      |
# |    time_elapsed     | 3098     |
# |    total_timesteps  | 644437   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0371   |
# |    n_updates        | 158609   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.14e+03 |
# |    ep_rew_mean      | 389      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2964     |
# |    fps              | 208      |
# |    time_elapsed     | 3101     |
# |    total_timesteps  | 645065   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 158766   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.15e+03 |
# |    ep_rew_mean      | 391      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2968     |
# |    fps              | 208      |
# |    time_elapsed     | 3105     |
# |    total_timesteps  | 646030   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0213   |
# |    n_updates        | 159007   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 388      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2972     |
# |    fps              | 208      |
# |    time_elapsed     | 3107     |
# |    total_timesteps  | 646423   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0268   |
# |    n_updates        | 159105   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 389      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2976     |
# |    fps              | 208      |
# |    time_elapsed     | 3112     |
# |    total_timesteps  | 647463   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0176   |
# |    n_updates        | 159365   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.12e+03 |
# |    ep_rew_mean      | 389      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2980     |
# |    fps              | 208      |
# |    time_elapsed     | 3115     |
# |    total_timesteps  | 648332   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 159582   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 390      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2984     |
# |    fps              | 208      |
# |    time_elapsed     | 3121     |
# |    total_timesteps  | 649468   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0252   |
# |    n_updates        | 159866   |
# ----------------------------------
# Eval num_timesteps=650000, episode_reward=430.00 +/- 132.74
# Episode length: 3653.60 +/- 464.51
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.65e+03 |
# |    mean_reward      | 430      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 650000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.103    |
# |    n_updates        | 159999   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 389      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2988     |
# |    fps              | 207      |
# |    time_elapsed     | 3137     |
# |    total_timesteps  | 650822   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0551   |
# |    n_updates        | 160205   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.13e+03 |
# |    ep_rew_mean      | 388      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2992     |
# |    fps              | 207      |
# |    time_elapsed     | 3141     |
# |    total_timesteps  | 651679   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0345   |
# |    n_updates        | 160419   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 387      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 2996     |
# |    fps              | 207      |
# |    time_elapsed     | 3146     |
# |    total_timesteps  | 652846   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0304   |
# |    n_updates        | 160711   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3000     |
# |    fps              | 207      |
# |    time_elapsed     | 3152     |
# |    total_timesteps  | 654012   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0249   |
# |    n_updates        | 161002   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3004     |
# |    fps              | 207      |
# |    time_elapsed     | 3154     |
# |    total_timesteps  | 654569   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.021    |
# |    n_updates        | 161142   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.11e+03 |
# |    ep_rew_mean      | 386      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3008     |
# |    fps              | 207      |
# |    time_elapsed     | 3158     |
# |    total_timesteps  | 655486   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0223   |
# |    n_updates        | 161371   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3012     |
# |    fps              | 207      |
# |    time_elapsed     | 3162     |
# |    total_timesteps  | 656232   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0911   |
# |    n_updates        | 161557   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3016     |
# |    fps              | 207      |
# |    time_elapsed     | 3165     |
# |    total_timesteps  | 656946   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0414   |
# |    n_updates        | 161736   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3020     |
# |    fps              | 207      |
# |    time_elapsed     | 3168     |
# |    total_timesteps  | 657640   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0273   |
# |    n_updates        | 161909   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 381      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3024     |
# |    fps              | 207      |
# |    time_elapsed     | 3172     |
# |    total_timesteps  | 658513   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0163   |
# |    n_updates        | 162128   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 383      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3028     |
# |    fps              | 207      |
# |    time_elapsed     | 3179     |
# |    total_timesteps  | 660074   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0548   |
# |    n_updates        | 162518   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.09e+03 |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3032     |
# |    fps              | 207      |
# |    time_elapsed     | 3182     |
# |    total_timesteps  | 660673   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.024    |
# |    n_updates        | 162668   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 379      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3036     |
# |    fps              | 207      |
# |    time_elapsed     | 3183     |
# |    total_timesteps  | 661062   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0377   |
# |    n_updates        | 162765   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04e+03 |
# |    ep_rew_mean      | 376      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3040     |
# |    fps              | 207      |
# |    time_elapsed     | 3188     |
# |    total_timesteps  | 662119   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0456   |
# |    n_updates        | 163029   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 378      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3044     |
# |    fps              | 207      |
# |    time_elapsed     | 3193     |
# |    total_timesteps  | 663131   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0286   |
# |    n_updates        | 163282   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04e+03 |
# |    ep_rew_mean      | 379      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3048     |
# |    fps              | 207      |
# |    time_elapsed     | 3198     |
# |    total_timesteps  | 664251   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.015    |
# |    n_updates        | 163562   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 381      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3052     |
# |    fps              | 207      |
# |    time_elapsed     | 3202     |
# |    total_timesteps  | 665222   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0112   |
# |    n_updates        | 163805   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 380      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3056     |
# |    fps              | 207      |
# |    time_elapsed     | 3206     |
# |    total_timesteps  | 665948   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0273   |
# |    n_updates        | 163986   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 382      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3060     |
# |    fps              | 207      |
# |    time_elapsed     | 3211     |
# |    total_timesteps  | 667146   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0682   |
# |    n_updates        | 164286   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 386      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3064     |
# |    fps              | 207      |
# |    time_elapsed     | 3217     |
# |    total_timesteps  | 668362   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0722   |
# |    n_updates        | 164590   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 381      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3068     |
# |    fps              | 207      |
# |    time_elapsed     | 3220     |
# |    total_timesteps  | 669186   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 164796   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3072     |
# |    fps              | 207      |
# |    time_elapsed     | 3224     |
# |    total_timesteps  | 670034   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0602   |
# |    n_updates        | 165008   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 382      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3076     |
# |    fps              | 207      |
# |    time_elapsed     | 3230     |
# |    total_timesteps  | 671283   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0505   |
# |    n_updates        | 165320   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 378      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3080     |
# |    fps              | 207      |
# |    time_elapsed     | 3232     |
# |    total_timesteps  | 671849   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0377   |
# |    n_updates        | 165462   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 380      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3084     |
# |    fps              | 207      |
# |    time_elapsed     | 3238     |
# |    total_timesteps  | 673154   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0251   |
# |    n_updates        | 165788   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 382      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3088     |
# |    fps              | 207      |
# |    time_elapsed     | 3243     |
# |    total_timesteps  | 674315   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0742   |
# |    n_updates        | 166078   |
# ----------------------------------
# Eval num_timesteps=675000, episode_reward=271.00 +/- 98.51
# Episode length: 2915.20 +/- 555.75
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 2.92e+03 |
# |    mean_reward      | 271      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 675000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0114   |
# |    n_updates        | 166249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3092     |
# |    fps              | 207      |
# |    time_elapsed     | 3257     |
# |    total_timesteps  | 675477   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0262   |
# |    n_updates        | 166369   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 387      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3096     |
# |    fps              | 207      |
# |    time_elapsed     | 3261     |
# |    total_timesteps  | 676341   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.022    |
# |    n_updates        | 166585   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3100     |
# |    fps              | 207      |
# |    time_elapsed     | 3264     |
# |    total_timesteps  | 677067   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0258   |
# |    n_updates        | 166766   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 387      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3104     |
# |    fps              | 207      |
# |    time_elapsed     | 3269     |
# |    total_timesteps  | 678128   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0211   |
# |    n_updates        | 167031   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04e+03 |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3108     |
# |    fps              | 207      |
# |    time_elapsed     | 3273     |
# |    total_timesteps  | 679075   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0186   |
# |    n_updates        | 167268   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04e+03 |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3112     |
# |    fps              | 207      |
# |    time_elapsed     | 3279     |
# |    total_timesteps  | 680314   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0605   |
# |    n_updates        | 167578   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.07e+03 |
# |    ep_rew_mean      | 387      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3116     |
# |    fps              | 207      |
# |    time_elapsed     | 3284     |
# |    total_timesteps  | 681530   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.048    |
# |    n_updates        | 167882   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3120     |
# |    fps              | 207      |
# |    time_elapsed     | 3289     |
# |    total_timesteps  | 682487   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0104   |
# |    n_updates        | 168121   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04e+03 |
# |    ep_rew_mean      | 383      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3124     |
# |    fps              | 207      |
# |    time_elapsed     | 3291     |
# |    total_timesteps  | 683094   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0362   |
# |    n_updates        | 168273   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3128     |
# |    fps              | 207      |
# |    time_elapsed     | 3296     |
# |    total_timesteps  | 684203   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0195   |
# |    n_updates        | 168550   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.03e+03 |
# |    ep_rew_mean      | 380      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3132     |
# |    fps              | 207      |
# |    time_elapsed     | 3301     |
# |    total_timesteps  | 685186   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0215   |
# |    n_updates        | 168796   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3136     |
# |    fps              | 207      |
# |    time_elapsed     | 3309     |
# |    total_timesteps  | 687134   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0348   |
# |    n_updates        | 169283   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3140     |
# |    fps              | 207      |
# |    time_elapsed     | 3314     |
# |    total_timesteps  | 688095   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0233   |
# |    n_updates        | 169523   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 388      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3144     |
# |    fps              | 207      |
# |    time_elapsed     | 3319     |
# |    total_timesteps  | 689319   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0233   |
# |    n_updates        | 169829   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3148     |
# |    fps              | 207      |
# |    time_elapsed     | 3324     |
# |    total_timesteps  | 690367   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0317   |
# |    n_updates        | 170091   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.06e+03 |
# |    ep_rew_mean      | 386      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3152     |
# |    fps              | 207      |
# |    time_elapsed     | 3327     |
# |    total_timesteps  | 691097   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 170274   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 386      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3156     |
# |    fps              | 207      |
# |    time_elapsed     | 3333     |
# |    total_timesteps  | 692279   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0531   |
# |    n_updates        | 170569   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.1e+03  |
# |    ep_rew_mean      | 388      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3160     |
# |    fps              | 207      |
# |    time_elapsed     | 3338     |
# |    total_timesteps  | 693566   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.123    |
# |    n_updates        | 170891   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.08e+03 |
# |    ep_rew_mean      | 388      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3164     |
# |    fps              | 207      |
# |    time_elapsed     | 3344     |
# |    total_timesteps  | 694682   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 171170   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.05e+03 |
# |    ep_rew_mean      | 384      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3168     |
# |    fps              | 207      |
# |    time_elapsed     | 3347     |
# |    total_timesteps  | 695375   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0126   |
# |    n_updates        | 171343   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.03e+03 |
# |    ep_rew_mean      | 380      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3172     |
# |    fps              | 207      |
# |    time_elapsed     | 3350     |
# |    total_timesteps  | 696032   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.069    |
# |    n_updates        | 171507   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.02e+03 |
# |    ep_rew_mean      | 379      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3176     |
# |    fps              | 207      |
# |    time_elapsed     | 3355     |
# |    total_timesteps  | 697188   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.023    |
# |    n_updates        | 171796   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.02e+03 |
# |    ep_rew_mean      | 379      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3180     |
# |    fps              | 207      |
# |    time_elapsed     | 3360     |
# |    total_timesteps  | 698143   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0194   |
# |    n_updates        | 172035   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.03e+03 |
# |    ep_rew_mean      | 381      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3184     |
# |    fps              | 207      |
# |    time_elapsed     | 3364     |
# |    total_timesteps  | 699093   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0251   |
# |    n_updates        | 172273   |
# ----------------------------------
# Eval num_timesteps=700000, episode_reward=543.00 +/- 146.03
# Episode length: 3492.40 +/- 528.47
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.49e+03 |
# |    mean_reward      | 543      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 700000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0464   |
# |    n_updates        | 172499   |
# ----------------------------------
# New best mean reward!
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.03e+03 |
# |    ep_rew_mean      | 383      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3188     |
# |    fps              | 207      |
# |    time_elapsed     | 3381     |
# |    total_timesteps  | 700545   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.018    |
# |    n_updates        | 172636   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04e+03 |
# |    ep_rew_mean      | 387      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3192     |
# |    fps              | 207      |
# |    time_elapsed     | 3385     |
# |    total_timesteps  | 701491   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.013    |
# |    n_updates        | 172872   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04e+03 |
# |    ep_rew_mean      | 386      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3196     |
# |    fps              | 207      |
# |    time_elapsed     | 3389     |
# |    total_timesteps  | 702377   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0379   |
# |    n_updates        | 173094   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.04e+03 |
# |    ep_rew_mean      | 385      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3200     |
# |    fps              | 207      |
# |    time_elapsed     | 3393     |
# |    total_timesteps  | 703164   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0736   |
# |    n_updates        | 173290   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.99e+03 |
# |    ep_rew_mean      | 377      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3204     |
# |    fps              | 207      |
# |    time_elapsed     | 3398     |
# |    total_timesteps  | 704254   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0463   |
# |    n_updates        | 173563   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.98e+03 |
# |    ep_rew_mean      | 375      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3208     |
# |    fps              | 207      |
# |    time_elapsed     | 3403     |
# |    total_timesteps  | 705499   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0146   |
# |    n_updates        | 173874   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.96e+03 |
# |    ep_rew_mean      | 370      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3212     |
# |    fps              | 207      |
# |    time_elapsed     | 3406     |
# |    total_timesteps  | 706135   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0128   |
# |    n_updates        | 174033   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.95e+03 |
# |    ep_rew_mean      | 370      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3216     |
# |    fps              | 207      |
# |    time_elapsed     | 3412     |
# |    total_timesteps  | 707356   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0205   |
# |    n_updates        | 174338   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 2.96e+03 |
# |    ep_rew_mean      | 373      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 3220     |
# |    fps              | 207      |
# |    time_elapsed     | 3417     |
# |    total_timesteps  | 708610   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0948   |
# |    n_updates        | 174652   |
# ----------------------------------
# ...
# |    learning_rate    | 0.0001   |
# |    loss             | 0.043    |
# |    n_updates        | 237205   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.74e+03 |
# |    ep_rew_mean      | 524      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4032     |
# |    fps              | 206      |
# |    time_elapsed     | 4652     |
# |    total_timesteps  | 960373   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0125   |
# |    n_updates        | 237593   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76e+03 |
# |    ep_rew_mean      | 526      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4036     |
# |    fps              | 206      |
# |    time_elapsed     | 4660     |
# |    total_timesteps  | 962281   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0374   |
# |    n_updates        | 238070   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76e+03 |
# |    ep_rew_mean      | 530      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4040     |
# |    fps              | 206      |
# |    time_elapsed     | 4665     |
# |    total_timesteps  | 963317   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0159   |
# |    n_updates        | 238329   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 529      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4044     |
# |    fps              | 206      |
# |    time_elapsed     | 4669     |
# |    total_timesteps  | 964179   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0107   |
# |    n_updates        | 238544   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 529      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4048     |
# |    fps              | 206      |
# |    time_elapsed     | 4676     |
# |    total_timesteps  | 965865   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0262   |
# |    n_updates        | 238966   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 529      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4052     |
# |    fps              | 206      |
# |    time_elapsed     | 4682     |
# |    total_timesteps  | 967128   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0295   |
# |    n_updates        | 239281   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76e+03 |
# |    ep_rew_mean      | 528      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4056     |
# |    fps              | 206      |
# |    time_elapsed     | 4689     |
# |    total_timesteps  | 968679   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0161   |
# |    n_updates        | 239669   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | 524      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4060     |
# |    fps              | 206      |
# |    time_elapsed     | 4694     |
# |    total_timesteps  | 969791   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0151   |
# |    n_updates        | 239947   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.72e+03 |
# |    ep_rew_mean      | 522      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4064     |
# |    fps              | 206      |
# |    time_elapsed     | 4698     |
# |    total_timesteps  | 970792   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0733   |
# |    n_updates        | 240197   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.73e+03 |
# |    ep_rew_mean      | 523      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4068     |
# |    fps              | 206      |
# |    time_elapsed     | 4702     |
# |    total_timesteps  | 971760   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0532   |
# |    n_updates        | 240439   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.75e+03 |
# |    ep_rew_mean      | 527      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4072     |
# |    fps              | 206      |
# |    time_elapsed     | 4711     |
# |    total_timesteps  | 973586   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0198   |
# |    n_updates        | 240896   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76e+03 |
# |    ep_rew_mean      | 531      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4076     |
# |    fps              | 206      |
# |    time_elapsed     | 4716     |
# |    total_timesteps  | 974901   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00729  |
# |    n_updates        | 241225   |
# ----------------------------------
# Eval num_timesteps=975000, episode_reward=616.00 +/- 267.63
# Episode length: 5135.00 +/- 1924.25
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 5.14e+03 |
# |    mean_reward      | 616      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 975000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0445   |
# |    n_updates        | 241249   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 532      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4080     |
# |    fps              | 206      |
# |    time_elapsed     | 4739     |
# |    total_timesteps  | 976603   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0196   |
# |    n_updates        | 241650   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81e+03 |
# |    ep_rew_mean      | 533      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4084     |
# |    fps              | 206      |
# |    time_elapsed     | 4744     |
# |    total_timesteps  | 977737   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0227   |
# |    n_updates        | 241934   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 529      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4088     |
# |    fps              | 206      |
# |    time_elapsed     | 4750     |
# |    total_timesteps  | 979005   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0204   |
# |    n_updates        | 242251   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | 527      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4092     |
# |    fps              | 206      |
# |    time_elapsed     | 4756     |
# |    total_timesteps  | 980365   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0248   |
# |    n_updates        | 242591   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.76e+03 |
# |    ep_rew_mean      | 526      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4096     |
# |    fps              | 206      |
# |    time_elapsed     | 4763     |
# |    total_timesteps  | 981895   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0646   |
# |    n_updates        | 242973   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.77e+03 |
# |    ep_rew_mean      | 526      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4100     |
# |    fps              | 206      |
# |    time_elapsed     | 4773     |
# |    total_timesteps  | 984327   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0105   |
# |    n_updates        | 243581   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 530      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4104     |
# |    fps              | 206      |
# |    time_elapsed     | 4780     |
# |    total_timesteps  | 985781   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00975  |
# |    n_updates        | 243945   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 533      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4108     |
# |    fps              | 206      |
# |    time_elapsed     | 4786     |
# |    total_timesteps  | 987123   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00653  |
# |    n_updates        | 244280   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.78e+03 |
# |    ep_rew_mean      | 528      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4112     |
# |    fps              | 206      |
# |    time_elapsed     | 4791     |
# |    total_timesteps  | 988142   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0446   |
# |    n_updates        | 244535   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81e+03 |
# |    ep_rew_mean      | 534      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4116     |
# |    fps              | 206      |
# |    time_elapsed     | 4800     |
# |    total_timesteps  | 990108   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.00842  |
# |    n_updates        | 245026   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 536      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4120     |
# |    fps              | 206      |
# |    time_elapsed     | 4806     |
# |    total_timesteps  | 991493   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0148   |
# |    n_updates        | 245373   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.82e+03 |
# |    ep_rew_mean      | 535      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4124     |
# |    fps              | 206      |
# |    time_elapsed     | 4812     |
# |    total_timesteps  | 992936   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0493   |
# |    n_updates        | 245733   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.81e+03 |
# |    ep_rew_mean      | 533      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4128     |
# |    fps              | 206      |
# |    time_elapsed     | 4818     |
# |    total_timesteps  | 994308   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0315   |
# |    n_updates        | 246076   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 530      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4132     |
# |    fps              | 206      |
# |    time_elapsed     | 4825     |
# |    total_timesteps  | 995877   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 246469   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.79e+03 |
# |    ep_rew_mean      | 533      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4136     |
# |    fps              | 206      |
# |    time_elapsed     | 4833     |
# |    total_timesteps  | 997639   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0245   |
# |    n_updates        | 246909   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 3.8e+03  |
# |    ep_rew_mean      | 536      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 4140     |
# |    fps              | 206      |
# |    time_elapsed     | 4840     |
# |    total_timesteps  | 999283   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0152   |
# |    n_updates        | 247320   |
# ----------------------------------
# Eval num_timesteps=1000000, episode_reward=479.00 +/- 115.78
# Episode length: 3722.40 +/- 808.69
# ----------------------------------
# | eval/               |          |
# |    mean_ep_length   | 3.72e+03 |
# |    mean_reward      | 479      |
# | rollout/            |          |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    total_timesteps  | 1000000  |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0367   |
# |    n_updates        | 247499   |
# ----------------------------------
# Saving to logs//dqn/SpaceInvadersNoFrameskip-v4_2

# %%
# !python enjoy.py --algo dqn --env SpaceInvadersNoFrameskip-v4 --no-render --n-timesteps 5000 --folder logs/
# Out:
# Loading latest experiment, id=2
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_2/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.7.4+069f8bd)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Atari Episode Score: 600.00
# Atari Episode Length 5056
# Atari Episode Score: 355.00
# Atari Episode Length 3388
# Atari Episode Score: 475.00
# Atari Episode Length 3842
# Atari Episode Score: 405.00
# Atari Episode Length 2638
# Atari Episode Score: 320.00
# Atari Episode Length 3053

# %%
from huggingface_hub import notebook_login
notebook_login()
# !git config --global credential.helper store
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token

# %%
# !python -m utils.push_to_hub --algo dqn --env SpaceInvadersNoFrameskip-v4 --repo-name dqn-SpaceInvadersNoFrameskip-v4 -orga spacestar1705 -f logs/
# Out:
# Loading latest experiment, id=2
# Loading logs/dqn/SpaceInvadersNoFrameskip-v4_2/SpaceInvadersNoFrameskip-v4.zip
# A.L.E: Arcade Learning Environment (version 0.7.4+069f8bd)
# [Powered by Stella]
# Stacking 4 frames
# Wrapping the env in a VecTransposeImage.
# Uploading to spacestar1705/dqn-SpaceInvadersNoFrameskip-v4, make sure to have the rights
# ℹ This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to some
# minutes if video generation is activated. This is a work in progress: if you
# encounter a bug, please open an issue.
# Cloning https://huggingface.co/spacestar1705/dqn-SpaceInvadersNoFrameskip-v4 into local empty directory.
# Saving video to /tmp/tmpnep_wdg3/-step-0-to-step-1000.mp4
# ffmpeg version 3.4.11-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.5.0-3ubuntu1~18.04)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --enable-gpl --disable-stripping --enable-avresample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librubberband --enable-librsvg --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-omx --enable-openal --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libopencv --enable-libx264 --enable-shared
#   libavutil      55. 78.100 / 55. 78.100
#   libavcodec     57.107.100 / 57.107.100
#   libavformat    57. 83.100 / 57. 83.100
#   libavdevice    57. 10.100 / 57. 10.100
#   libavfilter     6.107.100 /  6.107.100
#   libavresample   3.  7.  0 /  3.  7.  0
#   libswscale      4.  8.100 /  4.  8.100
#   libswresample   2.  9.100 /  2.  9.100
#   libpostproc    54.  7.100 / 54.  7.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/tmpnep_wdg3/-step-0-to-step-1000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#   Duration: 00:00:33.37, start: 0.000000, bitrate: 56 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 160x210, 53 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x559476c29900] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2 AVX512
# [libx264 @ 0x559476c29900] profile High, level 1.2
# [libx264 @ 0x559476c29900] 264 - core 152 r2854 e9a5903 - H.264/MPEG-4 AVC codec - Copyleft 2003-2017 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=3 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to 'hub/dqn-SpaceInvadersNoFrameskip-v4/replay.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf57.83.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 160x210, q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc57.107.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame= 1001 fps=0.0 q=-1.0 Lsize=     227kB time=00:00:33.26 bitrate=  55.8kbits/s speed=40.3x
# video:214kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.688309%
# [libx264 @ 0x559476c29900] frame I:5     Avg QP:18.46  size:  4087
# [libx264 @ 0x559476c29900] frame P:306   Avg QP:22.67  size:   539
# [libx264 @ 0x559476c29900] frame B:690   Avg QP:30.65  size:    48
# [libx264 @ 0x559476c29900] consecutive B-frames:  4.1%  8.8%  9.6% 77.5%
# [libx264 @ 0x559476c29900] mb I  I16..4: 22.3% 25.7% 52.0%
# [libx264 @ 0x559476c29900] mb P  I16..4:  0.5%  1.1%  1.3%  P16..4:  8.3%  3.9%  2.8%  0.0%  0.0%    skip:82.1%
# [libx264 @ 0x559476c29900] mb B  I16..4:  0.1%  0.2%  0.1%  B16..8:  9.3%  0.5%  0.0%  direct: 0.1%  skip:89.7%  L0:47.1% L1:52.7% BI: 0.2%
# [libx264 @ 0x559476c29900] 8x8 transform intra:34.7% inter:3.4%
# [libx264 @ 0x559476c29900] coded y,uvDC,uvAC intra: 27.8% 48.3% 45.8% inter: 1.5% 2.0% 1.7%
# [libx264 @ 0x559476c29900] i16 v,h,dc,p: 62% 34%  4%  0%
# [libx264 @ 0x559476c29900] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22%  8% 68%  1%  0%  0%  0%  0%  0%
# [libx264 @ 0x559476c29900] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 40% 12% 35%  2%  2%  3%  2%  2%  2%
# [libx264 @ 0x559476c29900] i8c dc,h,v,p: 55% 24% 20%  1%
# [libx264 @ 0x559476c29900] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x559476c29900] ref P L0: 72.4%  6.9% 10.4% 10.3%
# [libx264 @ 0x559476c29900] ref B L0: 81.7% 15.4%  2.9%
# [libx264 @ 0x559476c29900] ref B L1: 95.3%  4.7%
# [libx264 @ 0x559476c29900] kb/s:52.47
# ℹ Pushing repo dqn-SpaceInvadersNoFrameskip-v4 to the Hugging Face
# Hub
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:   0% 3.34k/26.0M [00:00<?, ?B/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:   0% 3.34k/12.9M [00:00<?, ?B/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:   0% 3.34k/12.9M [00:00<?, ?B/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100% 431/431 [00:00<?, ?B/s]
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:   2% 503k/26.0M [00:01<00:52, 511kB/s]
#
#
#
#
# Upload file replay.mp4:   1% 3.34k/227k [00:00<?, ?B/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:   1% 79.3k/12.9M [00:01<02:52, 77.6kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:   4% 1.01M/26.0M [00:02<00:49, 532kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:   6% 1.64M/26.0M [00:03<00:43, 590kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:   8% 1.03M/12.9M [00:03<00:29, 425kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:   9% 2.26M/26.0M [00:04<00:40, 612kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:   3% 331k/12.9M [00:04<02:36, 84.3kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:   6% 747k/12.9M [00:05<01:11, 179kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  18% 2.26M/12.9M [00:05<00:19, 561kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  10% 1.34M/12.9M [00:06<00:39, 310kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  10% 2.47M/26.0M [00:06<01:11, 346kB/s]
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  11% 2.87M/26.0M [00:07<01:06, 365kB/s]
#
#
#
#
# Upload file replay.mp4:  69% 155k/227k [00:06<00:02, 25.0kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  13% 3.48M/26.0M [00:08<00:53, 441kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  16% 2.07M/12.9M [00:08<00:31, 360kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  16% 4.09M/26.0M [00:09<00:46, 498kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  21% 2.67M/12.9M [00:09<00:24, 439kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  18% 4.70M/26.0M [00:10<00:41, 539kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  20% 5.32M/26.0M [00:11<00:37, 571kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  30% 3.90M/12.9M [00:11<00:17, 543kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  31% 3.98M/12.9M [00:11<00:33, 275kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  22% 5.65M/26.0M [00:12<00:42, 505kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  33% 4.27M/12.9M [00:12<00:32, 282kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  36% 4.66M/12.9M [00:13<00:27, 313kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  26% 6.87M/26.0M [00:14<00:35, 572kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  45% 5.73M/12.9M [00:14<00:12, 604kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  41% 5.27M/12.9M [00:14<00:20, 399kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  47% 6.10M/12.9M [00:15<00:13, 537kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  28% 7.40M/26.0M [00:15<00:34, 565kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  30% 7.86M/26.0M [00:16<00:35, 542kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  47% 6.03M/12.9M [00:16<00:18, 381kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  47% 6.07M/12.9M [00:17<00:25, 284kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  35% 9.09M/26.0M [00:18<00:29, 590kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  37% 9.68M/26.0M [00:19<00:28, 599kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  66% 8.56M/12.9M [00:19<00:07, 613kB/s]
#
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  40% 10.3M/26.0M [00:20<00:26, 609kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  71% 9.17M/12.9M [00:20<00:06, 619kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  42% 10.9M/26.0M [00:21<00:25, 620kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  50% 6.38M/12.9M [00:21<00:45, 151kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  44% 11.5M/26.0M [00:22<00:24, 628kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  76% 9.73M/12.9M [00:22<00:07, 470kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  59% 7.61M/12.9M [00:23<00:15, 358kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  77% 9.93M/12.9M [00:23<00:07, 405kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  64% 8.22M/12.9M [00:24<00:11, 431kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  82% 10.5M/12.9M [00:24<00:05, 466kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  69% 8.85M/12.9M [00:25<00:08, 493kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  87% 11.2M/12.9M [00:25<00:03, 518kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  74% 9.48M/12.9M [00:26<00:06, 539kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth:  92% 11.8M/12.9M [00:26<00:02, 557kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  79% 10.1M/12.9M [00:27<00:05, 575kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  47% 12.3M/26.0M [00:28<00:52, 272kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  84% 10.9M/12.9M [00:28<00:03, 638kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  52% 13.6M/26.0M [00:30<00:31, 418kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth:  95% 12.2M/12.9M [00:30<00:01, 658kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100% 12.9M/12.9M [00:30<00:00, 349kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip:  96% 24.9M/26.0M [00:40<00:00, 1.22MB/s]To https://huggingface.co/spacestar1705/dqn-SpaceInvadersNoFrameskip-v4
#    3c7564c..3b97230  main -> main
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4.zip: 100% 26.0M/26.0M [00:43<00:00, 632kB/s]
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100% 12.9M/12.9M [00:43<00:00, 114kB/s]
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.pth: 100% 12.9M/12.9M [00:43<00:00, 313kB/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/policy.optimizer.pth: 100% 12.9M/12.9M [00:43<00:00, 313kB/s]
#
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100% 431/431 [00:43<?, ?B/s]
#
#
# Upload file dqn-SpaceInvadersNoFrameskip-v4/pytorch_variables.pth: 100% 431/431 [00:43<?, ?B/s]
#
#
#
#
# Upload file train_eval_metrics.zip: 100% 36.9k/36.9k [00:43<00:00, 798B/s]
#
#
#
# Upload file train_eval_metrics.zip: 100% 36.9k/36.9k [00:43<00:00, 798B/s]
#
#
#
#
#
# Upload file replay.mp4: 100% 227k/227k [00:42<00:00, 3.87kB/s]
#
#
#
#
# Upload file replay.mp4: 100% 227k/227k [00:42<00:00, 5.43kB/s]
# ℹ Your model is pushed to the hub. You can view your model here:
# https://huggingface.co/spacestar1705/dqn-SpaceInvadersNoFrameskip-v4
